# %%
import pandas as pd 
import os

result = pd.DataFrame(columns=['time','Open','High','Low','Close'])
tickers = [f for f in os.listdir() if os.path.isfile(f) and f.split('.')[-1]=='csv']
for ticker in tickers:
    try:
        df = pd.read_csv(f'{ticker}', header=None, usecols=[0,1,2,3,4],names=['time','Open','High','Low','Close'])
        df['ticker'] = ticker.split('.')[0]
        result = pd.concat([result, df])
    except:
        print(ticker)
        break

from datetime import datetime, timedelta
result = result.iloc[1:,:]
def clean(d):
    d = str(d)[0:-6]
    return d

t = result['time'].apply(clean)
result['time'] = pd.to_datetime(t)

result.set_index('time')
# Out:
#                                    Open                High  \
# time
# 2022-10-19 09:30:00  41.630001068115234  41.709999084472656
# 2022-10-19 09:31:00  41.709999084472656  41.779998779296875
# 2022-10-19 09:32:00    41.7599983215332   41.83000183105469
# 2022-10-19 09:33:00   41.79999923706055   41.88999938964844
# 2022-10-19 09:34:00   41.93000030517578  41.935001373291016
# ...                                 ...                 ...
# 2022-11-11 15:55:00  27.475000381469727  27.479900360107422
# 2022-11-11 15:56:00  27.424999237060547  27.440000534057617
# 2022-11-11 15:57:00   27.40999984741211  27.415000915527344
# 2022-11-11 15:58:00  27.399999618530273   27.40999984741211
# 2022-11-11 15:59:00  27.399999618530273  27.420000076293945
#
#                                     Low               Close ticker
# time
# 2022-10-19 09:30:00   41.54999923706055  41.709999084472656   CSCO
# 2022-10-19 09:31:00   41.66999816894531   41.77000045776367   CSCO
# 2022-10-19 09:32:00    41.7599983215332   41.79499816894531   CSCO
# 2022-10-19 09:33:00   41.79999923706055  41.869998931884766   CSCO
# 2022-10-19 09:34:00  41.921600341796875  41.921600341796875   CSCO
# ...                                 ...                 ...    ...
# 2022-11-11 15:55:00   27.40999984741211  27.424999237060547    PPL
# 2022-11-11 15:56:00   27.40999984741211  27.415000915527344    PPL
# 2022-11-11 15:57:00  27.389999389648438  27.395000457763672    PPL
# 2022-11-11 15:58:00  27.389999389648438  27.405000686645508    PPL
# 2022-11-11 15:59:00  27.389999389648438  27.420000076293945    PPL
#
# [3306872 rows x 5 columns]

# %%
import os

curr = pd.Timestamp(year=2022, month=10, day=19)
end = datetime(year=2022, month=11, day=11)

while not curr == end:
    curr_str = curr.strftime('%Y-%m-%d')
    today = result[result['time'].dt.date.astype(str) == curr_str]
    path = os.path.dirname(os.path.abspath('split.ipynb'))+'/filtered/'+curr.strftime('%Y-%m-%d'+'.csv')
    today.to_csv(path)
    curr += pd.Timedelta(days = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [54], line 8
#       6 while not curr == end:
#       7     curr_str = curr.strftime('%Y-%m-%d')
# ----> 8     result[result['time'].dt.date.astype(str) == curr_str]
#       9     path = os.path.dirname(os.path.abspath('split.ipynb'))+'/filtered/'+curr.strftime('%Y-%m-%d'+'.csv')
#      10     result[mask].to_csv(path)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
#    6239         self.iloc[:, i].astype(dtype, copy=copy)
#    6240         for i in range(len(self.columns))
#    6241     ]
#    6243 else:
#    6244     # else, only a single dtype is given
# -> 6245     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6246     return self._constructor(new_data).__finalize__(self, method="astype")
#    6248 # GH 33113: handle empty frame or series
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/managers.py:446, in BaseBlockManager.astype(self, dtype, copy, errors)
#     445 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 446     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/managers.py:348, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     346         applied = b.apply(f, **kwargs)
#     347     else:
# --> 348         applied = getattr(b, f)(**kwargs)
#     349 except (TypeError, NotImplementedError):
#     350     if not ignore_failures:
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/internals/blocks.py:527, in Block.astype(self, dtype, copy, errors)
#     509 """
#     510 Coerce to the new dtype.
#     511
#    (...)
#     523 Block
#     524 """
#     525 values = self.values
# --> 527 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     529 new_values = maybe_coerce_values(new_values)
#     530 newb = self.make_block(new_values)
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/dtypes/astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/dtypes/astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/core/dtypes/astype.py:112, in astype_nansafe(arr, dtype, copy, skipna)
#     110     if arr.ndim > 1:
#     111         arr = arr.ravel()
# --> 112     return lib.ensure_string_array(
#     113         arr, skipna=skipna, convert_na_value=False
#     114     ).reshape(shape)
#     116 elif is_datetime64_dtype(arr.dtype):
#     117     if dtype == np.int64:
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/_libs/lib.pyx:703, in pandas._libs.lib.ensure_string_array()
#
# File ~/Library/Python/3.8/lib/python/site-packages/pandas/_libs/lib.pyx:762, in pandas._libs.lib.ensure_string_array()
#
# KeyboardInterrupt:

# %%
# Out:
# /Users/jialechen/Documents/GitHub/backtestingdata/filtered/2022-11-11.csv
